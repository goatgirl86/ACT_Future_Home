# %% [markdown]
# # CPI Data

# %% [markdown]
# ## Original Data

# %%
import pandas as pd
import numpy as np

# %%
df12=pd.read_excel("C:/Users/twmgp/Documents/Data Analytics/Alumni/ACT_Future_Home/Katlin/oesm12nat/national_M2012_dl.xls")
df12.head(5)
# Out:
#   OCC_CODE               OCC_TITLE OCC_GROUP    TOT_EMP  EMP_PRSE H_MEAN  \
# 0  00-0000         All Occupations     total  130287700       0.1  22.01
# 1  11-0000  Management Occupations     major    6390430       0.2   52.2
# 2  11-1000          Top Executives     minor    2212150       0.2  57.72
# 3  11-1010        Chief Executives     broad     255940       0.6  85.02
# 4  11-1011        Chief Executives  detailed     255940       0.6  85.02
#
#    A_MEAN  MEAN_PRSE H_PCT10 H_PCT25 H_MEDIAN H_PCT75 H_PCT90 A_PCT10 A_PCT25  \
# 0   45790        0.1     8.7   10.81    16.71   27.02   41.74   18090   22480
# 1  108570        0.1   22.12   31.56    45.15    65.2       #   46000   65650
# 2  120060        0.2   21.81   32.04    47.86   74.63       #   45370   66630
# 3  176840        0.3   36.65   52.86    80.84       #       #   76220  109940
# 4  176840        0.3   36.65   52.86    80.84       #       #   76220  109940
#
#   A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# ...

# %%
#pip install openpyxl

# %%
import openpyxl

# %%
df13=pd.read_excel("C:/Users/twmgp/Documents/Data Analytics/Alumni/ACT_Future_Home/Katlin/oesm13nat/national_M2013_dl.xls")
df14=pd.read_excel("C:/Users/twmgp/Documents/Data Analytics/Alumni/ACT_Future_Home/Katlin/oesm14nat/national_M2014_dl.xlsx")
df15=pd.read_excel("C:/Users/twmgp/Documents/Data Analytics/Alumni/ACT_Future_Home/Katlin/oesm15nat/national_M2015_dl.xlsx")
df16=pd.read_excel("C:/Users/twmgp/Documents/Data Analytics/Alumni/ACT_Future_Home/Katlin/oesm16nat/national_M2016_dl.xlsx")
df17=pd.read_excel("C:/Users/twmgp/Documents/Data Analytics/Alumni/ACT_Future_Home/Katlin/oesm17nat/national_M2017_dl.xlsx")
df18=pd.read_excel("C:/Users/twmgp/Documents/Data Analytics/Alumni/ACT_Future_Home/Katlin/oesm18nat/national_M2018_dl.xlsx")
df19=pd.read_excel("C:/Users/twmgp/Documents/Data Analytics/Alumni/ACT_Future_Home/Katlin/oesm19nat/national_M2019_dl.xlsx")
df20=pd.read_excel("C:/Users/twmgp/Documents/Data Analytics/Alumni/ACT_Future_Home/Katlin/oesm20nat/national_M2020_dl.xlsx")
df21=pd.read_excel("C:/Users/twmgp/Documents/Data Analytics/Alumni/ACT_Future_Home/Katlin/oesm21nat/national_M2021_dl.xlsx")

# %%
df12.columns
# Out:
# Index(['OCC_CODE', 'OCC_TITLE', 'OCC_GROUP', 'TOT_EMP', 'EMP_PRSE', 'H_MEAN',
#        'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN', 'H_PCT75',
#        'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75', 'A_PCT90',
#        'ANNUAL', 'HOURLY'],
#       dtype='object')

# %%
df19.columns
# Out:
# Index(['area', 'area_title', 'area_type', 'naics', 'naics_title', 'i_group',
#        'own_code', 'occ_code', 'occ_title', 'o_group', 'tot_emp', 'emp_prse',
#        'jobs_1000', 'loc_quotient', 'pct_total', 'h_mean', 'a_mean',
#        'mean_prse', 'h_pct10', 'h_pct25', 'h_median', 'h_pct75', 'h_pct90',
#        'a_pct10', 'a_pct25', 'a_median', 'a_pct75', 'a_pct90', 'annual',
#        'hourly'],
#       dtype='object')

# %%
df19.rename(columns={'area': 'AREA', 'area_title': 'AREA_TITLE', 'area_type':'AREA_TYPE', 'naics':'NAICS', 'naics_title':'NAICS_TITLE', 'i_group':'I_GROUP',
       'own_code':'OWN_GROUP', 'occ_code':'OWN_CODE', 'occ_title':'OCC_TITLE', 'o_group':'OCC_GROUP','tot_emp':'TOT_EMP', 'emp_prse':'EMP_PRSE',
       'jobs_1000':'JOBS_1000', 'loc_quotient':'LOC_QUOTIENT', 'pct_total':'PCT_TOTAL', 'h_mean':'H_MEAN', 'a_mean':'A_MEAN',
       'mean_prse':'MEAN_PRSE', 'h_pct10':'H_PCT10', 'h_pct25':'H_PCT25', 'h_median':'H_MEDIAN', 'h_pct75':'H_PCT75', 'h_pct90':'H_PCT90',
       'a_pct10':'A_PCT10', 'a_pct25':'A_PCT25', 'a_median':'A_MEDIAN', 'a_pct75':'A_PCT75', 'a_pct90':'A_PCT90', 'annual':'ANNUAL',
       'hourly':'HOURLY'}, inplace = True)

# %%
df19
# Out:
#       AREA AREA_TITLE  AREA_TYPE  NAICS     NAICS_TITLE         I_GROUP  \
# 0       99       U.S.          1      0  Cross-industry  cross-industry
# 1       99       U.S.          1      0  Cross-industry  cross-industry
# 2       99       U.S.          1      0  Cross-industry  cross-industry
# 3       99       U.S.          1      0  Cross-industry  cross-industry
# 4       99       U.S.          1      0  Cross-industry  cross-industry
# ...    ...        ...        ...    ...             ...             ...
# 1324    99       U.S.          1      0  Cross-industry  cross-industry
# 1325    99       U.S.          1      0  Cross-industry  cross-industry
# 1326    99       U.S.          1      0  Cross-industry  cross-industry
# 1327    99       U.S.          1      0  Cross-industry  cross-industry
# 1328    99       U.S.          1      0  Cross-industry  cross-industry
#
#       OWN_GROUP OWN_CODE                                  OCC_TITLE OCC_GROUP  \
# ...

# %%
df19.columns
# Out:
# Index(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'NAICS', 'NAICS_TITLE', 'I_GROUP',
#        'OWN_GROUP', 'OWN_CODE', 'OCC_TITLE', 'OCC_GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'H_MEAN',
#        'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN', 'H_PCT75',
#        'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75', 'A_PCT90',
#        'ANNUAL', 'HOURLY'],
#       dtype='object')

# %%
df19.drop(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'NAICS', 'NAICS_TITLE',
       'I_GROUP',  'OWN_GROUP', 'OWN_CODE',  'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL',], axis=1, inplace=True)

# %%
df20.columns
# Out:
# Index(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'PRIM_STATE', 'NAICS', 'NAICS_TITLE',
#        'I_GROUP', 'OWN_CODE', 'OCC_CODE', 'OCC_TITLE', 'O_GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'H_MEAN',
#        'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN', 'H_PCT75',
#        'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75', 'A_PCT90',
#        'ANNUAL', 'HOURLY'],
#       dtype='object')

# %%
df20.drop(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'PRIM_STATE','NAICS', 'NAICS_TITLE',
       'I_GROUP', 'OWN_CODE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL',], axis=1, inplace=True)

# %%
df21.columns
# Out:
# Index(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'PRIM_STATE', 'NAICS', 'NAICS_TITLE',
#        'I_GROUP', 'OWN_CODE', 'OCC_CODE', 'OCC_TITLE', 'O_GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'PCT_RPT',
#        'H_MEAN', 'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN',
#        'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75',
#        'A_PCT90', 'ANNUAL', 'HOURLY'],
#       dtype='object')

# %%
df21.drop(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'PRIM_STATE','NAICS', 'NAICS_TITLE',
       'I_GROUP', 'OWN_CODE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL','PCT_RPT'], axis=1, inplace=True)

# %%
df18.columns
# Out:
# Index(['OCC_CODE', 'OCC_TITLE', 'OCC_GROUP', 'TOT_EMP', 'EMP_PRSE', 'H_MEAN',
#        'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN', 'H_PCT75',
#        'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75', 'A_PCT90',
#        'ANNUAL', 'HOURLY'],
#       dtype='object')

# %%
df21.rename(columns={'O_GROUP':'OCC_GROUP'}, inplace=True)

# %%
df20.rename(columns={'O_GROUP':'OCC_GROUP'}, inplace=True)

# %%
df12 = df12.assign(YEAR='2012')
df12
# Out:
#      OCC_CODE                              OCC_TITLE OCC_GROUP    TOT_EMP  \
# 0     00-0000                        All Occupations     total  130287700
# 1     11-0000                 Management Occupations     major    6390430
# 2     11-1000                         Top Executives     minor    2212150
# 3     11-1010                       Chief Executives     broad     255940
# 4     11-1011                       Chief Executives  detailed     255940
# ...       ...                                    ...       ...        ...
# 1389  53-7111             Mine Shuttle Car Operators  detailed       2990
# 1390  53-7120      Tank Car, Truck, and Ship Loaders     broad      12390
# 1391  53-7121      Tank Car, Truck, and Ship Loaders  detailed      12390
# 1392  53-7190  Miscellaneous Material Moving Workers     broad      27260
# 1393  53-7199     Material Moving Workers, All Other  detailed      27260
#
#       EMP_PRSE H_MEAN  A_MEAN  MEAN_PRSE H_PCT10 H_PCT25  ... H_PCT75 H_PCT90  \
# ...

# %%
df12 = df12.assign(YEAR='2012')
df13 = df13.assign(YEAR='2013')
df14 = df14.assign(YEAR='2014')
df15 = df15.assign(YEAR='2015')
df16 = df16.assign(YEAR='2016')
df17 = df17.assign(YEAR='2017')
df18 = df18.assign(YEAR='2018')
df19 = df19.assign(YEAR='2019')
df20 = df20.assign(YEAR='2020')
df21 = df21.assign(YEAR='2021')

# %%
df20
# Out:
#      OCC_CODE                                  OCC_TITLE OCC_GROUP    TOT_EMP  \
# 0     00-0000                            All Occupations     total  139099570
# 1     11-0000                     Management Occupations     major    7947300
# 2     11-1000                             Top Executives     minor    2601070
# 3     11-1010                           Chief Executives     broad     202360
# 4     11-1011                           Chief Executives  detailed     202360
# ...       ...                                        ...       ...        ...
# 1324  53-7081  Refuse and Recyclable Material Collectors  detailed     120850
# 1325  53-7120          Tank Car, Truck, and Ship Loaders     broad      12610
# 1326  53-7121          Tank Car, Truck, and Ship Loaders  detailed      12610
# 1327  53-7190      Miscellaneous Material Moving Workers     broad      26300
# 1328  53-7199         Material Moving Workers, All Other  detailed      26300
#
# ...

# %%
df12_major=df12.loc[(df12["OCC_GROUP"]=="major")]
df13_major=df13.loc[(df13["OCC_GROUP"]=="major")]
df14_major=df14.loc[(df14["OCC_GROUP"]=="major")]
df15_major=df15.loc[(df15["OCC_GROUP"]=="major")]
df16_major=df16.loc[(df16["OCC_GROUP"]=="major")]
df17_major=df17.loc[(df17["OCC_GROUP"]=="major")]
df18_major=df18.loc[(df18["OCC_GROUP"]=="major")]
df19_major=df19.loc[(df19["OCC_GROUP"]=="major")]
df20_major=df20.loc[(df20["OCC_GROUP"]=="major")]
df21_major=df21.loc[(df21["OCC_GROUP"]=="major")]

# %%
df_major_all = pd.concat([df12_major,df13_major, df14_major, df15_major, df16_major, df17_major, df18_major, df19_major, df20_major, df21_major])

# %%
df_major_all
# Out:
#      OCC_CODE                                          OCC_TITLE OCC_GROUP  \
# 1     11-0000                             Management Occupations     major
# 70    13-0000      Business and Financial Operations Occupations     major
# 128   15-0000              Computer and Mathematical Occupations     major
# 161   17-0000           Architecture and Engineering Occupations     major
# 221   19-0000     Life, Physical, and Social Science Occupations     major
# ...       ...                                                ...       ...
# 943   45-0000         Farming, Fishing, and Forestry Occupations     major
# 967   47-0000            Construction and Extraction Occupations     major
# 1070  49-0000  Installation, Maintenance, and Repair Occupations     major
# 1145  51-0000                             Production Occupations     major
# 1312  53-0000     Transportation and Material Moving Occupations     major
#
# ...

# %%
df_major_all.to_csv('df_major_all.csv')
