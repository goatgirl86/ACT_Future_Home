# %% [markdown]
# # CPI Data

# %% [markdown]
# ## Original Data

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/twmgp/Documents/Data Analytics/Alumni/ACT_Future_Home/CPI_data/consumer_expenditure_2012-2022(dollar).csv")
df.head(5)
# Out:
#     Region  Year Month    Food  Alcoholic_beverages  Housing  Apparel  \
# 0  Western  2012   Jan  597.59                41.86  1562.35   146.22
# 1  Western  2012   Feb  597.31                42.28  1566.44   147.28
# 2  Western  2012   Mar  598.56                42.16  1569.44   151.53
# 3  Western  2012   Apr  599.49                42.04  1571.54   153.41
# 4  Western  2012   May  599.20                42.11  1576.40   152.77
#
#    Transportation  Healthcare  Entertainment  Education_and_communication  \
# 0          864.25      331.66         293.87                        99.38
# 1          878.88      333.64         293.44                        99.45
# 2          913.32      334.50         293.81                        99.62
# 3          918.00      334.75         293.86                        99.62
# 4          922.98      336.31         292.84                        99.80
#
#    Other_goods_and_services
# 0                    874.25
# 1                    872.89
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### General Stats

# %%
region_mean=df.groupby(["Region"]).mean()
region_mean
# Out:
# C:\Users\twmgp\AppData\Local\Temp\ipykernel_20600\563718230.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   region_mean=df.groupby(["Region"]).mean()
#                   Year        Food  Alcoholic_beverages      Housing  \
# Region
# All        2016.892857  609.103000            40.881000  1681.876214
# Midwest    2016.892857  585.497786            41.909929  1546.162214
# Northeast  2016.892857  687.550071            50.054429  1977.315571
# South      2016.892857  554.093643            33.242357  1511.619000
# Western    2016.892857  666.490286            46.067643  1877.278143
#
#               Apparel  Transportation  Healthcare  Entertainment  \
# Region
# All        138.744857      858.546000  402.465786     261.581143
# ...

# %%
region_sum=df.groupby(["Region"]).sum()
region_sum
# Out:
# C:\Users\twmgp\AppData\Local\Temp\ipykernel_20600\2366756502.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   region_sum=df.groupby(["Region"]).sum()
#              Year      Food  Alcoholic_beverages    Housing   Apparel  \
# Region
# All        282365  85274.42              5723.34  235462.67  19424.28
# Midwest    282365  81969.69              5867.39  216462.71  20245.48
# Northeast  282365  96257.01              7007.62  276824.18  23613.43
# South      282365  77573.11              4653.93  211626.66  16224.59
# Western    282365  93308.64              6449.47  262818.94  20942.18
#
#            Transportation  Healthcare  Entertainment  \
# Region
# All             120196.44    56345.21       36621.36
# Midwest         119686.43    61729.49       39845.28
# ...

# %% [markdown]
# ### Grouping Data

# %%
year_sum=df.groupby(["Year"]).sum()
year_sum
# Out:
# C:\Users\twmgp\AppData\Local\Temp\ipykernel_20600\2378853178.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   year_sum=df.groupby(["Year"]).sum()
#           Food  Alcoholic_beverages    Housing  Apparel  Transportation  \
# Year
# 2012  36944.06              2578.80   98585.78  9421.27        56473.92
# 2013  37446.21              2620.64  100628.20  9502.82        56477.22
# 2014  38336.55              2650.30  103183.75  9521.25        56079.01
# 2015  39043.24              2674.40  105221.46  9407.97        51730.49
# 2016  39162.80              2707.10  107811.48  9418.58        50593.98
# 2017  39507.91              2738.49  110967.84  9392.36        52275.65
# 2018  40083.64              2779.56  114171.65  9374.24        54623.75
# ...

# %%
year_mean=df.groupby(["Year"]).mean()
year_mean
# Out:
# C:\Users\twmgp\AppData\Local\Temp\ipykernel_20600\3594010891.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   year_mean=df.groupby(["Year"]).mean()
#             Food  Alcoholic_beverages      Housing     Apparel  \
# Year
# 2012  568.370154            39.673846  1516.704308  144.942615
# 2013  576.095538            40.317538  1548.126154  146.197231
# 2014  589.793077            40.773846  1587.442308  146.480769
# 2015  600.665231            41.144615  1618.791692  144.738000
# 2016  602.504615            41.647692  1658.638154  144.901231
# 2017  607.814000            42.130615  1707.197538  144.497846
# 2018  616.671385            42.762462  1756.486923  144.219077
# 2019  628.187692            43.290462  1806.426154  142.390923
# ...

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 163.6/163.6 kB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 kB 1.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 965.4/965.4 kB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 1.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
from matplotlib import pyplot as plt

# %%
# Create the plot
year_mean.plot()
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
year_mean.plot.bar()
plt.legend(loc='upper right', borderpad=2)
plt.figure(figsize=(50,20))

# %%
year_mean.plot.scatter('Food',"Alcoholic_beverages")
# Out:
# <AxesSubplot: xlabel='Food', ylabel='Alcoholic_beverages'>
